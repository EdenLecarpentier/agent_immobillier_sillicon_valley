# %% [markdown]
# # This is the notebook_eda used for data cleaning :)

# %%
from sklearn.model_selection import KFold , StratifiedKFold
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import statsmodels.api as sm
from sklearn.model_selection import learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("C:/Users/edenl/Desktop/ia_coding/agent_immobilier_sillicon_valley/dataset.csv")
df
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [raw]
# let's analyze the dataset and see what we could delete are use

# %%
df.dropna(inplace=True)
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [raw]
# Here we are deleting the NaN values then checking with the function info if it worked

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %% [raw]
# We are checkingthe data types to see if we have any data that needs to have a type change

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [raw]
# lets see if we have some values with 0

# %%
df[df == 0].count()
# Out:
# Unnamed: 0            1
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [raw]
# we are going to drop the 0 values

# %%
df = df.drop("Unnamed: 0" , 1)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %% [raw]
# drop the column Unnamed: 0

# %%
df.to_csv('silicon_valley_good_data.csv', index=False)

# %% [raw]
# this converts all the change we did in to a new dataset named silicon_valley_good_data and it will be a csv file
