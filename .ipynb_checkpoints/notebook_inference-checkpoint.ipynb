# %% [markdown]
# # This is the notebook_inference used for data vizualisation :)

# %%
from sklearn.model_selection import KFold , StratifiedKFold
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import statsmodels.api as sm
from sklearn.model_selection import learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("C:/Users/edenl/Desktop/ia_coding/agent_immobilier_sillicon_valley/silicon_valley_good_data.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16331    -121.90     39.59                20.0       1465.0           278.0
# 16332    -122.25     38.11                49.0       2365.0           504.0
# 16333    -121.22     38.92                19.0       2531.0           461.0
# 16334    -118.14     34.16                39.0       2776.0           840.0
# 16335    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %% [raw]
# this is to read are new dataset we created with notebook_eda

# %%
sns.scatterplot(x=df["housing_median_age"] , y=df["median_income"])
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='median_income'>

# %% [raw]
# here we compared the housing_median_age and the median_income
# has we can see the median_age is a good bet to found the best income but they are still a lot of data going a little everywhere(outliers) we should be carefull

# %%
sns.scatterplot(x=df["median_income"] , y=df["ocean_proximity"])
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='ocean_proximity'>

# %% [raw]
# i am looking for a house at least one hour away from the ocean because (near_bay , inland , near_ocean ) aren't the one that cost the most money

# %%
sns.scatterplot(x=df["total_bedrooms"] , y=df["population"])
# Out:
# <AxesSubplot:xlabel='total_bedrooms', ylabel='population'>

# %% [raw]
# it's a simple verification but it's essentiel so here we are comparing the population to the number of bedrooms to see if its in accordance
# some of the population are not where the most bedrooms are but mainly the median value will be the best where there is a lot of bedrooms

# %%
sns.scatterplot(x=df["total_rooms"] , y=df["population"])
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='population'>

# %% [raw]
# same constation than above

# %%
sns.pairplot(df)

# %% [raw]
# we can see a lot of points going a little everywhere(ouliers) this can mean the dataset is not clean enought are that those values are normal
# they are different values but different doesn't mean bad if im not wrong

# %% [raw]
# conclusion it seems like being 1hour away from the sea in a old house where there is a lot of population and where there is a clusters of rooms and bedrooms is the best median value
